% %%
clc
clear
close all
tic
%%
Pathname = ['D:\dataset\健康人数据' filesep 'data_64'] ;
Listing = dir(Pathname) ;
filename = {Listing(3:end).name}' ;
% 获取文件名并使用natsort进行排序
filename = natsort(filename);
Fz=6;
time=linspace(-100,600,350);
for isSub =1:20
    isSub
    Pathname1 = [Pathname filesep filename{isSub}] ;
    Listing1 = dir(Pathname1) ;
    filename1 = {Listing1(3:end).name}' ;
    for days=1:3
        Data=load( [Pathname1 filesep filename1{days} filesep 'epoched.mat'] );
        Avg_STD(isSub,days,:,:) = squeeze(mean(Data.STD,3));
        Avg_STD_fre(isSub,days,:,:) = squeeze(mean(Data.STD_fre,3));
        Avg_STD_name(isSub,days,:,:) = squeeze(mean(Data.STD_name(:,:,1:250),3));
        Avg_STD_In(isSub,days,:,:) = squeeze(mean(Data.STD_In,3));
        Avg_STD_time(isSub,days,:,:) = squeeze(mean(Data.STD_time,3));
        
        Avg_DEV_Fre(isSub,days,:,:) = squeeze(mean(Data.DEV_Fre,3));
        Avg_DEV_name(isSub,days,:,:) = squeeze(mean(Data.DEV_name(:,:,1:250),3));
        Avg_DEV_time(isSub,days,:,:) = squeeze(mean(Data.DEV_time,3));
        Avg_DEV_In(isSub,days,:,:) = squeeze(mean(Data.DEV_In,3));
        
        
        Diff_DEV_Fre_DI(isSub,days,:,:) = Avg_DEV_Fre(isSub,days,:,:) - Avg_STD_fre(isSub,days,:,:);
        Diff_DEV_name_DI(isSub,days,:,:) = Avg_DEV_name(isSub,days,:,:) - Avg_STD_name(isSub,days,:,:);
        Diff_DEV_time_DI(isSub,days,:,:) = Avg_DEV_time(isSub,days,:,:) - Avg_STD_time(isSub,days,:,:);
        Diff_DEV_In_DI(isSub,days,:,:) = Avg_DEV_In(isSub,days,:,:) - Avg_STD_In(isSub,days,:,:);
    end
end
Mean_STD_day1=squeeze(mean(Avg_STD(:,1,Fz,:),1)); %% select the data at Fz, average across subjects, mean_data1: 300*1
Mean_DEV_Fre_day1=squeeze(mean(Avg_DEV_Fre(:,1,Fz,:),1));
Mean_DEV_name_day1=squeeze(mean(Avg_DEV_name(:,1,Fz,:),1));
Mean_DEV_time_day1=squeeze(mean(Avg_DEV_time(:,1,Fz,:),1));
Mean_DEV_In_day1=squeeze(mean(Avg_DEV_In(:,1,Fz,:),1));

Mean_DEV_Fre_DI_day1=squeeze(mean(Diff_DEV_Fre_DI(:,1,Fz,:),1));
Mean_DEV_name_DI_day1=squeeze(mean(Diff_DEV_name_DI(:,1,Fz,:),1));
Mean_DEV_time_DI_day1=squeeze(mean(Diff_DEV_time_DI(:,1,Fz,:),1));
Mean_DEV_In_DI_day1=squeeze(mean(Diff_DEV_In_DI(:,1,Fz,:),1));

Mean_STD_day2=squeeze(mean(Avg_STD(:,2,Fz,:),1)); %% select the data at Fz, average across subjects, mean_data1: 300*1
Mean_DEV_Fre_day2=squeeze(mean(Avg_DEV_Fre(:,2,Fz,:),1));
Mean_DEV_name_day2=squeeze(mean(Avg_DEV_name(:,2,Fz,:),1));
Mean_DEV_time_day2=squeeze(mean(Avg_DEV_time(:,2,Fz,:),1));
Mean_DEV_In_day2=squeeze(mean(Avg_DEV_In(:,2,Fz,:),1));

Mean_DEV_Fre_DI_day2=squeeze(mean(Diff_DEV_Fre_DI(:,2,Fz,:),1));
Mean_DEV_name_DI_day2=squeeze(mean(Diff_DEV_name_DI(:,2,Fz,:),1));
Mean_DEV_time_DI_day2=squeeze(mean(Diff_DEV_time_DI(:,2,Fz,:),1));
Mean_DEV_In_DI_day2=squeeze(mean(Diff_DEV_In_DI(:,2,Fz,:),1));

Mean_STD_day3=squeeze(mean(Avg_STD(:,3,Fz,:),1)); %% select the data at Fz, average across subjects, mean_data1: 300*1
Mean_DEV_Fre_day3=squeeze(mean(Avg_DEV_Fre(:,3,Fz,:),1));
Mean_DEV_name_day3=squeeze(mean(Avg_DEV_name(:,3,Fz,:),1));
Mean_DEV_time_day3=squeeze(mean(Avg_DEV_time(:,3,Fz,:),1));
Mean_DEV_In_day3=squeeze(mean(Avg_DEV_In(:,3,Fz,:),1));

Mean_DEV_Fre_DI_day3=squeeze(mean(Diff_DEV_Fre_DI(:,3,Fz,:),1));
Mean_DEV_name_DI_day3=squeeze(mean(Diff_DEV_name_DI(:,3,Fz,:),1));
Mean_DEV_time_DI_day3=squeeze(mean(Diff_DEV_time_DI(:,3,Fz,:),1));
Mean_DEV_In_DI_day3=squeeze(mean(Diff_DEV_In_DI(:,3,Fz,:),1));
%% STD
%% 方差阴影
figure(1);
time=linspace(-100,600,350);%时间-100 500 取300个点
y1=plot(time, Mean_STD_day1,'b','linewidth', 1.5, 'DisplayName', '第一次'); %% plot the waveforms
hold on
% 计算并绘制方差阴影
std_shade_day1 = squeeze(std(Avg_STD(:, 1, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day1 = Mean_STD_day1 + std_shade_day1;
lower_bound_day1 = Mean_STD_day1 - std_shade_day1;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day1', fliplr(lower_bound_day1')], 'b', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on;
y2=plot(time,  Mean_STD_day2,'r','linewidth', 1.5, 'DisplayName', '第二次'); %% plot the waveforms
% 计算并绘制方差阴影
std_shade_day2 = squeeze(std(Avg_STD(:, 2, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day2 = Mean_STD_day2 + std_shade_day2;
lower_bound_day2 = Mean_STD_day2 - std_shade_day2;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day2', fliplr(lower_bound_day2')], 'r', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
y3=plot(time,  Mean_STD_day3,'k','linewidth', 1.5, 'DisplayName', '第三次'); %% plot the waveforms
% 计算并绘制方差阴影
std_shade_day3 = squeeze(std(Avg_STD(:, 3, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day3 = Mean_STD_day3 + std_shade_day3;
lower_bound_day3 = Mean_STD_day3 - std_shade_day3;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day3', fliplr(lower_bound_day3')], 'k', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
% 移除图形窗口的边框
box off;
%% 存在检验
%first day
%% N1
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_STD_day1(90:126)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_STD_day1(70:135)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_group_N1 =peak_locs(max_peak_loc)+70;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_group_N1 =peak_locs(max_peak_loc)+90;
peak_time_1=location_in_group_N1-10;
peak_time_2=location_in_group_N1+10;
amp_group_N1=squeeze(mean(Mean_STD_day1( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_group_N1);
t_test_N1=Mean_STD_day1(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    figure(1)
    y_bottom = min(amp_group_N1) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'b', 'FaceAlpha', 0.1);
    hold on;
else
end
%% P2
[pks,peak_locs,w,p] = findpeaks(squeeze(Mean_STD_day1(111:201)));%选择80-150ms内的数
[max_peak_num,max_peak_loc] = max(pks);
location_in_group_P2 =peak_locs(max_peak_loc)+111;
peak_time_1_P2=location_in_group_P2-10;
peak_time_2_P2=location_in_group_P2+10;
amp_group_P2=squeeze(mean(Mean_STD_day1( peak_time_1_P2:peak_time_2_P2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_P2=time(1,location_in_group_P2);
t_test_P2=Mean_STD_day1(peak_time_1_P2:peak_time_2_P2);
[h,p,ci,stats] = ttest(t_test_P2, 0, 'Tail', 'right');
if h == 1
    figure(1)
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1_P2), time(peak_time_1_P2), time(peak_time_2_P2), time(peak_time_2_P2)], [-2, -1.5, -1.5, -2], 'b', 'FaceAlpha', 0.1);
    hold on;
else
end
%% second
%% N1
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_STD_day2(90:126)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_STD_day2(70:135)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_group_N1 =peak_locs(max_peak_loc)+70;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_group_N1 =peak_locs(max_peak_loc)+90;
peak_time_1=location_in_group_N1-10;
peak_time_2=location_in_group_N1+10;
amp_group_N1=squeeze(mean(Mean_STD_day2( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_group_N1);
t_test_N1=Mean_STD_day2(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    figure(1)
    y_bottom = min(amp_group_N1) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'r', 'FaceAlpha', 0.1);
    hold on;
else
end
%% P2
[pks,peak_locs,w,p] = findpeaks(squeeze(Mean_STD_day2(111:201)));%选择80-150ms内的数
[max_peak_num,max_peak_loc] = max(pks);
location_in_group_P2 =peak_locs(max_peak_loc)+111;
peak_time_1_P2=location_in_group_P2-10;
peak_time_2_P2=location_in_group_P2+10;
amp_group_P2=squeeze(mean(Mean_STD_day2( peak_time_1_P2:peak_time_2_P2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_P2=time(1,location_in_group_P2);
t_test_P2=Mean_STD_day2(peak_time_1_P2:peak_time_2_P2);
[h,p,ci,stats] = ttest(t_test_P2, 0, 'Tail', 'right');
if h == 1
    figure(1)
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1_P2), time(peak_time_1_P2), time(peak_time_2_P2), time(peak_time_2_P2)], [-2, -1.5, -1.5, -2], 'r', 'FaceAlpha', 0.1);
    hold on;
else
end
%% third
%% N1
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_STD_day3(90:126)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_STD_day3(70:135)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_group_N1 =peak_locs(max_peak_loc)+70;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_group_N1 =peak_locs(max_peak_loc)+90;
peak_time_1=location_in_group_N1-10;
peak_time_2=location_in_group_N1+10;
amp_group_N1=squeeze(mean(Mean_STD_day3( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_group_N1);
t_test_N1=Mean_STD_day3(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    figure(1)
    y_bottom = min(amp_group_N1) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end
%% P2
[pks,peak_locs,w,p] = findpeaks(squeeze(Mean_STD_day3(111:201)));%选择80-150ms内的数
[max_peak_num,max_peak_loc] = max(pks);
location_in_group_P2 =peak_locs(max_peak_loc)+111;
peak_time_1_P2=location_in_group_P2-10;
peak_time_2_P2=location_in_group_P2+10;
amp_group_P2=squeeze(mean(Mean_STD_day3( peak_time_1_P2:peak_time_2_P2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_P2=time(1,location_in_group_P2);
t_test_P2=Mean_STD_day3(peak_time_1_P2:peak_time_2_P2);
[h,p,ci,stats] = ttest(t_test_P2, 0, 'Tail', 'right');
if h == 1
    figure(1)
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1_P2), time(peak_time_1_P2), time(peak_time_2_P2), time(peak_time_2_P2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end
% 添加图例
legend([y1, y2, y3], '第一次', '第二次', '第三次', 'Location', 'northeast');
% set(gca,'YDir','reverse'); %% reverse the direction of Y axis
axis([-100 600 -2 2]);  %% define the region to displa
hold on
xlabel('时间 (ms)','fontsize',25); %% name of X axi
ylabel('幅值 (\muV)','fontsize',25);
title('Group STD','fontsize',30);
%% NAME
%% 方差阴影
figure(2);
time=linspace(-100,600,350);%时间-100 500 取300个点
y1=plot(time, Mean_DEV_name_DI_day1,'b','linewidth', 1.5, 'DisplayName', '第一次'); %% plot the waveforms
hold on
% 计算并绘制方差阴影
std_name_day1 = squeeze(std(Avg_STD_name(:, 1, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day1 = Mean_DEV_name_DI_day1 + std_name_day1;
lower_bound_day1 =Mean_DEV_name_DI_day1 - std_name_day1;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day1', fliplr(lower_bound_day1')], 'b', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on;
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_name_DI_day1(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_name_DI_day1(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_name_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_name_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_name_MMN-10;
peak_time_2=location_in_name_MMN+10;
amp_name_MMN=squeeze(mean(Mean_DEV_name_DI_day1( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_name_MMN);
t_test_N1=Mean_DEV_name_DI_day1(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_name_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y2=plot(time,  Mean_DEV_name_DI_day2,'r','linewidth', 1.5, 'DisplayName', '第二次'); %% plot the waveforms
% 计算并绘制方差阴影
std_name_day2 = squeeze(std(Avg_STD_name(:, 2, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day2 = Mean_DEV_name_DI_day2 + std_name_day2;
lower_bound_day2 = Mean_DEV_name_DI_day2 - std_name_day2;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day2', fliplr(lower_bound_day2')], 'r', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_name_DI_day2(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_name_DI_day2(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_name_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_name_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_name_MMN-10;
peak_time_2=location_in_name_MMN+10;
amp_name_MMN=squeeze(mean(Mean_DEV_name_DI_day2( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_name_MMN);
t_test_N1=Mean_DEV_name_DI_day2(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_name_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y3=plot(time,  Mean_DEV_name_DI_day3,'k','linewidth', 1.5, 'DisplayName', '第三次'); %% plot the waveforms
% 计算并绘制方差阴影
std_name_day3 = squeeze(std(Avg_STD_name(:, 3, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day3 = Mean_DEV_name_DI_day3 + std_name_day3;
lower_bound_day3 = Mean_DEV_name_DI_day3 - std_name_day3;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day3', fliplr(lower_bound_day3')], 'k', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_name_DI_day3(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_name_DI_day3(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_name_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_name_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_name_MMN-10;
peak_time_2=location_in_name_MMN+10;
amp_name_MMN=squeeze(mean(Mean_DEV_name_DI_day3( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_name_MMN);
t_test_N1=Mean_DEV_name_DI_day3(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_name_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

% 移除图形窗口的边框
box off;
% 添加图例
legend([y1, y2, y3], '第一次', '第二次', '第三次', 'Location', 'northeast');
% set(gca,'YDir','reverse'); %% reverse the direction of Y axis
axis([-100 600 -2 2]);  %% define the region to displa
hold on
xlabel('时间 (ms)','fontsize',25); %% name of X axi
ylabel('幅值 (\muV)','fontsize',25);
title('Group Name','fontsize',30);
%% fre
%% 方差阴影
figure(3);
time=linspace(-100,600,350);%时间-100 500 取300个点
y1=plot(time, Mean_DEV_Fre_DI_day1,'b','linewidth', 1.5, 'DisplayName', '第一次'); %% plot the waveforms
hold on
% 计算并绘制方差阴影
std_fre_day1 = squeeze(std(Avg_STD_fre(:, 1, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day1 = Mean_DEV_Fre_DI_day1 + std_fre_day1;
lower_bound_day1 =Mean_DEV_Fre_DI_day1 - std_fre_day1;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day1', fliplr(lower_bound_day1')], 'b', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on;
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_Fre_DI_day1(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_Fre_DI_day1(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_Fre_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_Fre_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_Fre_MMN-10;
peak_time_2=location_in_Fre_MMN+10;
amp_Fre_MMN=squeeze(mean(Mean_DEV_Fre_DI_day1( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_Fre_MMN);
t_test_N1=Mean_DEV_Fre_DI_day1(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_Fre_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y2=plot(time,  Mean_DEV_Fre_DI_day2,'r','linewidth', 1.5, 'DisplayName', '第二次'); %% plot the waveforms
% 计算并绘制方差阴影
std_fre_day2 = squeeze(std(Avg_STD_fre(:, 2, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day2 = Mean_DEV_Fre_DI_day2 + std_fre_day2;
lower_bound_day2 = Mean_DEV_Fre_DI_day2 - std_fre_day2;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day2', fliplr(lower_bound_day2')], 'r', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_Fre_DI_day2(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_Fre_DI_day2(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_Fre_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_Fre_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_Fre_MMN-10;
peak_time_2=location_in_Fre_MMN+10;
amp_Fre_MMN=squeeze(mean(Mean_DEV_Fre_DI_day2( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_Fre_MMN);
t_test_N1=Mean_DEV_Fre_DI_day2(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_Fre_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y3=plot(time,  Mean_DEV_Fre_DI_day3,'k','linewidth', 1.5, 'DisplayName', '第三次'); %% plot the waveforms
% 计算并绘制方差阴影
std_fre_day3 = squeeze(std(Avg_STD_fre(:, 3, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day3 = Mean_DEV_Fre_DI_day3 + std_fre_day3;
lower_bound_day3 = Mean_DEV_Fre_DI_day3 - std_fre_day3;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day3', fliplr(lower_bound_day3')], 'k', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_Fre_DI_day3(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_Fre_DI_day3(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_Fre_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_Fre_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_Fre_MMN-10;
peak_time_2=location_in_Fre_MMN+10;
amp_Fre_MMN=squeeze(mean(Mean_DEV_Fre_DI_day3( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_Fre_MMN);
t_test_N1=Mean_DEV_Fre_DI_day3(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_Fre_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

% 移除图形窗口的边框
box off;
% 添加图例
legend([y1, y2, y3], '第一次', '第二次', '第三次', 'Location', 'northeast');
% set(gca,'YDir','reverse'); %% reverse the direction of Y axis
axis([-100 600 -2 2]);  %% define the region to displa
hold on
xlabel('时间 (ms)','fontsize',25); %% name of X axi
ylabel('幅值 (\muV)','fontsize',25);
title('Group Fre','fontsize',30);
%% time
figure(4);
time=linspace(-100,600,350);%时间-100 500 取300个点
y1=plot(time, Mean_DEV_time_DI_day1,'b','linewidth', 1.5, 'DisplayName', '第一次'); %% plot the waveforms
hold on
% 计算并绘制方差阴影
std_time_day1 = squeeze(std(Avg_STD_time(:, 1, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day1 = Mean_DEV_time_DI_day1 + std_time_day1;
lower_bound_day1 =Mean_DEV_time_DI_day1 - std_time_day1;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day1', fliplr(lower_bound_day1')], 'b', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on;
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_time_DI_day1(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_time_DI_day1(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_time_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_time_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_time_MMN-10;
peak_time_2=location_in_time_MMN+10;
amp_time_MMN=squeeze(mean(Mean_DEV_time_DI_day1( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_time_MMN);
t_test_N1=Mean_DEV_time_DI_day1(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_time_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y2=plot(time,  Mean_DEV_time_DI_day2,'r','linewidth', 1.5, 'DisplayName', '第二次'); %% plot the waveforms
% 计算并绘制方差阴影
std_time_day2 = squeeze(std(Avg_STD_time(:, 2, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day2 = Mean_DEV_time_DI_day2 + std_time_day2;
lower_bound_day2 = Mean_DEV_time_DI_day2 - std_time_day2;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day2', fliplr(lower_bound_day2')], 'r', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_time_DI_day2(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_time_DI_day2(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_time_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_time_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_time_MMN-10;
peak_time_2=location_in_time_MMN+10;
amp_time_MMN=squeeze(mean(Mean_DEV_time_DI_day2( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_time_MMN);
t_test_N1=Mean_DEV_time_DI_day2(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_time_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y3=plot(time,  Mean_DEV_time_DI_day3,'k','linewidth', 1.5, 'DisplayName', '第三次'); %% plot the waveforms
% 计算并绘制方差阴影
std_time_day3 = squeeze(std(Avg_STD_time(:, 3, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day3 = Mean_DEV_time_DI_day3 + std_time_day3;
lower_bound_day3 = Mean_DEV_time_DI_day3 - std_time_day3;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day3', fliplr(lower_bound_day3')], 'k', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_time_DI_day3(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_time_DI_day3(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_time_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_time_MMN =peak_locs(max_peak_loc)+108;
peak_time_1=location_in_time_MMN-10;
peak_time_2=location_in_time_MMN+10;
amp_time_MMN=squeeze(mean(Mean_DEV_time_DI_day3( peak_time_1:peak_time_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_time_group_N1=time(1,location_in_time_MMN);
t_test_N1=Mean_DEV_time_DI_day3(peak_time_1:peak_time_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_time_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_time_1), time(peak_time_1), time(peak_time_2), time(peak_time_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end
% 移除图形窗口的边框
box off;
% 添加图例
legend([y1, y2, y3], '第一次', '第二次', '第三次', 'Location', 'northeast');
% set(gca,'YDir','reverse'); %% reverse the direction of Y axis
axis([-100 600 -2 2]);  %% define the region to displa
hold on
xlabel('时间 (ms)','fontsize',25); %% name of X axi
ylabel('幅值 (\muV)','fontsize',25);
title('Group Time','fontsize',30);
%% In
figure(5);
time=linspace(-100,600,350);%时间-100 500 取300个点
y1=plot(time, Mean_DEV_In_DI_day1,'b','linewidth', 1.5, 'DisplayName', '第一次'); %% plot the waveforms
hold on
% 计算并绘制方差阴影
std_In_day1 = squeeze(std(Avg_STD_In(:, 1, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day1 = Mean_DEV_In_DI_day1 + std_In_day1;
lower_bound_day1 =Mean_DEV_In_DI_day1 - std_In_day1;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day1', fliplr(lower_bound_day1')], 'b', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on;
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_In_DI_day1(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_In_DI_day1(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_In_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_In_MMN =peak_locs(max_peak_loc)+108;
peak_In_1=location_in_In_MMN-10;
peak_In_2=location_in_In_MMN+10;
amp_In_MMN=squeeze(mean(Mean_DEV_In_DI_day1( peak_In_1:peak_In_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_In_group_N1=time(1,location_in_In_MMN);
t_test_N1=Mean_DEV_In_DI_day1(peak_In_1:peak_In_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_In_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_In_1), time(peak_In_1), time(peak_In_2), time(peak_In_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y2=plot(time,  Mean_DEV_In_DI_day2,'r','linewidth', 1.5, 'DisplayName', '第二次'); %% plot the waveforms
% 计算并绘制方差阴影
std_In_day2 = squeeze(std(Avg_STD_In(:, 2, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day2 = Mean_DEV_In_DI_day2 + std_In_day2;
lower_bound_day2 = Mean_DEV_In_DI_day2 - std_In_day2;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day2', fliplr(lower_bound_day2')], 'r', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_In_DI_day2(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_In_DI_day2(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_In_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_In_MMN =peak_locs(max_peak_loc)+108;
peak_In_1=location_in_In_MMN-10;
peak_In_2=location_in_In_MMN+10;
amp_In_MMN=squeeze(mean(Mean_DEV_In_DI_day2( peak_In_1:peak_In_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_In_group_N1=time(1,location_in_In_MMN);
t_test_N1=Mean_DEV_In_DI_day2(peak_In_1:peak_In_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_In_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_In_1), time(peak_In_1), time(peak_In_2), time(peak_In_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end

y3=plot(time,  Mean_DEV_In_DI_day3,'k','linewidth', 1.5, 'DisplayName', '第三次'); %% plot the waveforms
% 计算并绘制方差阴影
std_In_day3 = squeeze(std(Avg_STD_In(:, 3, Fz, :), 0, 1));  % 计算每个时间点的方差
upper_bound_day3 = Mean_DEV_In_DI_day3 + std_In_day3;
lower_bound_day3 = Mean_DEV_In_DI_day3 - std_In_day3;
%% 标准差
fill([time, fliplr(time)], [upper_bound_day3', fliplr(lower_bound_day3')], 'k', 'EdgeColor', 'none', 'FaceAlpha', 0.2 );
hold on
[pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_In_DI_day3(108:176)));%选择80-150ms内的数
if isempty(pks)
    [pks,peak_locs,w,p] = findpeaks(-squeeze(Mean_DEV_In_DI_day3(98:186)));
    [max_peak_num,max_peak_loc] = max(pks);
    location_in_In_MMN =peak_locs(max_peak_loc)+98;
else
end
[max_peak_num,max_peak_loc] = max(pks);
location_in_In_MMN =peak_locs(max_peak_loc)+108;
peak_In_1=location_in_In_MMN-10;
peak_In_2=location_in_In_MMN+10;
amp_In_MMN=squeeze(mean(Mean_DEV_In_DI_day3( peak_In_1:peak_In_2),1));
%     location_in_x_N1(isSub,days) = find(-squeeze(STD(days,Cz,:))==max_peak_num);
peak_In_group_N1=time(1,location_in_In_MMN);
t_test_N1=Mean_DEV_In_DI_day3(peak_In_1:peak_In_2);
[h,p,ci,stats] = ttest(t_test_N1, 0, 'Tail', 'left');
if h == 1
    y_bottom = min(amp_In_MMN) - 0.5; % 从下边框开始
    % 使用 fill 函数创建一个高度为 0.5 的矩形区域
    fill([time(peak_In_1), time(peak_In_1), time(peak_In_2), time(peak_In_2)], [-2, -1.5, -1.5, -2], 'k', 'FaceAlpha', 0.1);
    hold on;
else
end
% 移除图形窗口的边框
box off;
% 添加图例
legend([y1, y2, y3], '第一次', '第二次', '第三次', 'Location', 'northeast');
% set(gca,'YDir','reverse'); %% reverse the direction of Y axis
axis([-100 600 -2 2]);  %% define the region to displa
hold on
xlabel('时间 (ms)','fontsize',25); %% name of X axi
ylabel('幅值 (\muV)','fontsize',25);
title('Group In','fontsize',30);
% Out:
% isSub =
%
%      1
%
%
% isSub =
%
%      2
%
%
% isSub =
%
%      3
%
%
% isSub =
%
%      4
%
%
% isSub =
%
%      5
%
%
% isSub =
%
%      6
%
%
% isSub =
%
%      7
%
%
% isSub =
%
%      8
%
%
% isSub =
%
%      9
%
%
% isSub =
%
%     10
%
%
% isSub =
%
%     11
%
%
% isSub =
%
%     12
%
%
% isSub =
%
%     13
%
%
% isSub =
%
%     14
%
%
% isSub =
%
%     15
%
%
% isSub =
%
%     16
%
%
% isSub =
%
%     17
%
%
% isSub =
%
%     18
%
%
% isSub =
%
%     19
%
%
% isSub =
%
%     20
